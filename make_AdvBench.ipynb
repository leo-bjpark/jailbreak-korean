# %%
import json 

translation = json.load(open("outputs/google/gemma-3-12b-it/AdvBench/seed_42/translation.json"))

# %%
ds = {
    'prompt': translation['prompt'],
    'target': translation['target']
}

import datasets 
ds = datasets.Dataset.from_dict(ds)
ds
# Out:
# Dataset({
#     features: ['prompt', 'target'],
#     num_rows: 520
# })

# %%
ds[0]

ds.push_to_hub("leo-bjpark/AdvBench-Korean")
# Out:
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 331.17ba/s]
# Processing Files (1 / 1): 100%|██████████| 39.6kB / 39.6kB, 22.0kB/s
# New Data Upload: 100%|██████████| 39.6kB / 39.6kB, 22.0kB/s
# Uploading the dataset shards: 100%|██████████| 1/1 [00:02<00:00,  2.84s/ shards]
# CommitInfo(commit_url='https://huggingface.co/datasets/leo-bjpark/AdvBench-Korean/commit/d555f33a3b3767409f99131cf70d306bafe27f2f', commit_message='Upload dataset', commit_description='', oid='d555f33a3b3767409f99131cf70d306bafe27f2f', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/leo-bjpark/AdvBench-Korean', endpoint='https://huggingface.co', repo_type='dataset', repo_id='leo-bjpark/AdvBench-Korean'), pr_revision=None, pr_num=None)
